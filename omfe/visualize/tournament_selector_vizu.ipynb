# %%
import mga
import numpy as np
import matplotlib.pyplot as plt
from problems import ChankongHaimes
from problems import BinhKorn
from evaluator import NonDominatedSortEvaluator
from evaluator import WeightBasedEvaluator
from tournament_selector import TournamentSelector

# %%
problem = ChankongHaimes()
evaluator = WeightBasedEvaluator(problem)
tournament_evaluator = NonDominatedSortEvaluator(problem)
MGA = mga.MicroGeneticAlgorithm(
    problem,
    evaluator,
    population_size=5,
    agents_to_keep=5,
    agents_to_shuffle=4,
    random_restarts=1000,
    max_iterations=1000,
    iteration_tolerance=40,
    num_bits=12,
    random_seed=42,
)
TMS = TournamentSelector(
    MGA,
    tournament_evaluator,
    tournament_size=50,
    num_tournaments=50,
    num_iterations=10,
)
TMS.run_iterations()
# Out:
# RUNNING SETUP
# SETUP FINISHED
# Iteration 1, number of winners: 578
# Iteration 2, number of winners: 1541
# Iteration 3, number of winners: 2059
# Iteration 4, number of winners: 2305
# Iteration 5, number of winners: 2403
# Iteration 6, number of winners: 2462
# Iteration 7, number of winners: 2470
# Iteration 8, number of winners: 2481
# Iteration 9, number of winners: 2481
# Iteration 10, number of winners: 2494

# %%
nr_winners = len(TMS.contenders)
f1 = np.zeros((nr_winners))
f2 = np.zeros((nr_winners))
for i in range(nr_winners):
    f1[i] = problem.f_1(TMS.contenders[i])
    f2[i] = problem.f_2(TMS.contenders[i])

# %%
plt.scatter(f1,f2)

# %%
import benchmark_chankong_haimes as bm
from pymoo.optimize import minimize
from pymoo.core.problem import ElementwiseProblem
from pymoo.visualization.scatter import Scatter

# Predefined Problems, Algorithms and Terminations
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.util.termination.default import MultiObjectiveDefaultTermination

# %%
problem = bm.ChankongHaimes()
algorithm = NSGA2()
termination = MultiObjectiveDefaultTermination()
result = minimize(
    problem,
    algorithm,
    termination,
    pf=True,
    seed=1,
    save_history=True,
    verbose=True,
)
plot = Scatter(title="Chankong and Haimes Function")
plot.add(result.F, facecolor="none", edgecolor="red", alpha=0.8, s=20)
plot.show()
# Out:
# =====================================================================================
# n_gen |  n_eval |   cv (min)   |   cv (avg)   |  n_nds  |     eps      |  indicator
# =====================================================================================
#     1 |     100 |  0.00000E+00 |  2.305424903 |       8 |            - |            -
#     2 |     200 |  0.00000E+00 |  0.250132126 |      16 |  0.024880199 |        ideal
#     3 |     300 |  0.00000E+00 |  0.00000E+00 |      32 |  0.026203941 |            f
#     4 |     400 |  0.00000E+00 |  0.00000E+00 |      40 |  0.027512832 |        ideal
#     5 |     500 |  0.00000E+00 |  0.00000E+00 |      53 |  0.064919532 |        ideal
#     6 |     600 |  0.00000E+00 |  0.00000E+00 |      65 |  0.013277327 |        ideal
#     7 |     700 |  0.00000E+00 |  0.00000E+00 |      92 |  0.019554246 |        ideal
#     8 |     800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.003012999 |            f
#     9 |     900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.002666277 |            f
#    10 |    1000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.002250196 |            f
#    11 |    1100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.037730429 |        nadir
#    12 |    1200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001544583 |            f
#    13 |    1300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.019460786 |        ideal
#    14 |    1400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001390853 |            f
#    15 |    1500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001653066 |            f
#    16 |    1600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.003855050 |        nadir
#    17 |    1700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001404195 |            f
#    18 |    1800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001610373 |            f
#    19 |    1900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001066270 |            f
#    20 |    2000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.005002156 |        ideal
#    21 |    2100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001360455 |            f
#    22 |    2200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001612380 |            f
#    23 |    2300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001542011 |            f
#    24 |    2400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.002225552 |            f
#    25 |    2500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001413314 |            f
#    26 |    2600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001180955 |            f
#    27 |    2700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001307328 |            f
#    28 |    2800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001597573 |            f
#    29 |    2900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001258416 |            f
#    30 |    3000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001474160 |            f
#    31 |    3100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001354269 |            f
#    32 |    3200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001496502 |            f
#    33 |    3300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001215234 |            f
#    34 |    3400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001476044 |            f
#    35 |    3500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001793770 |            f
#    36 |    3600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001360482 |            f
#    37 |    3700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001295243 |            f
#    38 |    3800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001368406 |            f
#    39 |    3900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001173220 |            f
#    40 |    4000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001486443 |            f
#    41 |    4100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001432958 |            f
#    42 |    4200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001651453 |            f
#    43 |    4300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001375275 |            f
#    44 |    4400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001460973 |            f
#    45 |    4500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001502240 |            f
#    46 |    4600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001486195 |            f
#    47 |    4700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001102483 |            f
#    48 |    4800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001665282 |            f
#    49 |    4900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001447414 |            f
#    50 |    5000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001115807 |            f

# %%
f = np.vstack((f1, f2)).T
#f = f[:100][:]
plot = Scatter(title="Chankong and Haimes Function")
plot.add(result.F, facecolor="none", edgecolor="red", alpha=0.8, s=20)
plot.add(f, facecolor="none", edgecolor="blue", alpha=0.8, s=20)
plot.show()
