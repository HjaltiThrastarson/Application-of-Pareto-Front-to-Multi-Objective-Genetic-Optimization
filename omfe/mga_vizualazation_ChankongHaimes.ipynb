# %%
import mga
import numpy as np
import matplotlib.pyplot as plt
from problems import ChankongHaimes
from evaluator import NonDominatedSortEvaluator
from evaluator import WeightBasedEvaluator
from mga import AlgorithmRunner, MicroGeneticAlgorithm
from visualize import plot_chankong_haimes_pareto_front, plot_agents

# %%
seed=42
problem = ChankongHaimes()
evaluator = WeightBasedEvaluator(problem, seed)
random_restarts = 200
mga = MicroGeneticAlgorithm(
    problem,
    evaluator=evaluator,
    population_size=11,
    agents_to_keep=1,
    max_iterations=50,
    num_bits=8,
    seed=seed,
)
runner = AlgorithmRunner(mga, seed=42)
best_agents = runner.run(times=random_restarts)

# %%
fig, ax = plt.subplots()
plot_agents(ax, best_agents, problem)
ax.scatter(f1, f2)
plot_chankong_haimes_pareto_front(ax)
